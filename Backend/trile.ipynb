# %%
from langchain_ollama import ChatOllama
import requests

# %%
url = "http://localhost:11434/api/generate"

payload = {
    "model": 'llama3.2',
    "prompt": "What is the name of the biggest flower in the world ?",
    "stream" : False
}

result = requests.post(url,json = payload).json()
response = result['response']
print(response.strip())
# Out:
# The Rafflesia arnoldii, also known as the "Corpse Lily," is often considered the largest individual flower in the world. However, it's not a single flower that blooms at once, but rather a parasitic plant that produces massive flowers.
#
# Each bloom can reach up to 3 feet (90 cm) in diameter and weigh around 24 pounds (11 kg). The Rafflesia arnoldii is native to the rainforests of Southeast Asia, particularly in Indonesia and Malaysia.
#
# It's worth noting that while it's the largest individual flower, the Titan Arum (Amorphophallus titanum) is often referred to as the "largest flower" due to its massive inflorescence, which can reach up to 10 feet (3 meters) tall. However, this is actually a collection of multiple flowers that bloom together, rather than a single large flower.
#
# So, while there's no single answer to your question, the Rafflesia arnoldii is often considered one of the largest individual flowers in the world!
